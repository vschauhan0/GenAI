# %% [markdown]
# # Assignmnet 13
#
# ## Data Gathering, pre-processing and EDA

# %% [markdown]
# ### Dataset link
# ### https://www.kaggle.com/datasets/daniilkrizhanovskyi/mlops-dataset

# %% [markdown]
# ## Part 1 : Data Gathring

# %% [markdown]
# ### Task 1: Load Data From CSV

# %%
import pandas as pd

# %%
df = pd.read_csv('mlops_dataset.csv')

# %%
df.shape
# Out:
# (100, 16)
