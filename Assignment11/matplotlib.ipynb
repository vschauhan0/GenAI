# %% [markdown]
# ## Assignment 11: Matplotlib

# %% [markdown]
# ### Dataset = T20 World Cup 2026 Match Dataset
# #### Link = https://www.kaggle.com/datasets/vishardmehta/t20-world-cup-2026-match-dataset

# %%
import pandas as pd

# %%
data = pd.read_csv('Match_dataset.csv')

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Match_ID        Date    Venue        Team_A        Team_B   Stage  \
# 0      M0001  2026-03-06  Chennai   New Zealand      Scotland  Super8
# 1      M0002  2026-03-07   Mumbai  South Africa     Sri Lanka   Final
# 2      M0003  2026-03-02  Kolkata         India           PNG   Group
# 3      M0004  2026-02-22  Colombo   Netherlands       Ireland   Group
# 4      M0005  2026-02-28   Mumbai       Namibia  South Africa   Group
# ..       ...         ...      ...           ...           ...     ...
# 595    M0596  2026-02-12  Kolkata       England      Zimbabwe   Group
# 596    M0597  2026-02-14  Colombo     Australia       England   Group
# 597    M0598  2026-02-13  Chennai        Canada     Australia   Group
# 598    M0599  2026-02-21    Delhi       Namibia      Pakistan   Group
# 599    M0600  2026-02-07    Delhi   Netherlands        Canada   Group
#
#      Team_A_Ranking  Team_B_Ranking  Team_A_Form  Team_B_Form  ...  \
# ...

# %%
df.head()
# Out:
#   Match_ID        Date    Venue        Team_A        Team_B   Stage  \
# 0    M0001  2026-03-06  Chennai   New Zealand      Scotland  Super8
# 1    M0002  2026-03-07   Mumbai  South Africa     Sri Lanka   Final
# 2    M0003  2026-03-02  Kolkata         India           PNG   Group
# 3    M0004  2026-02-22  Colombo   Netherlands       Ireland   Group
# 4    M0005  2026-02-28   Mumbai       Namibia  South Africa   Group
#
#    Team_A_Ranking  Team_B_Ranking  Team_A_Form  Team_B_Form  ...  \
# 0               5              13        76.97        54.62  ...
# 1               6               9        64.19        58.75  ...
# 2               1              20        69.87        45.14  ...
# 3              11              12        85.59        61.94  ...
# 4              15               6        45.98        88.52  ...
#
#    HeadToHead_B_Wins  Venue_HomeAdvantage_A  Venue_HomeAdvantage_B  \
# 0                  4                      0                      0
# ...
